# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivendrahappy/MITOCW-60001-Python-Lec-2-branching-iteration-/blob/main/MITOCW_60001_Python_Lec_2_branching_iteration_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hi= "Hello there"
name= "Ana"
greet=(hi + name)
print(greet)
# Out:
# Hello thereAna

# %% [markdown]
# for space bet there and Ana use " " space

# %%
hi= "Hello there"
name= "Ana"
greet=(hi+" "+name)
print(greet)
# Out:
# Hello there Ana

# %% [markdown]
# Name 3 times by *

# %%
hi= "Hello there"
name= "Ana"
silly=hi+(" "+name)*3
print(silly)
# Out:
# Hello there Ana Ana Ana
